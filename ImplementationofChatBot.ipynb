# %% [markdown]
# # Implementation of Chatbot using NLP

# %%
pip install nltk scikit-learn streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing necessary libraries
import nltk
import random
import os
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl._create_default_https_context = ssl._create_unverified_context
nltk.data.path.append(os.path.abspath('nltk_data'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/raghunandanms/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
intents = [
    {
        'tag': 'greeting',
        'patterns': ['Hi', 'Hello', 'Hey', 'What’s up', 'How are you', 'Good morning', 'Good evening'],
        'responses': ['Hi there!', 'Hello!', 'Hey!', 'Not much, how about you?', 'I’m doing well, thanks for asking!']
    },
    {
        'tag': 'goodbye',
        'patterns': ['Bye', 'See you later', 'Goodbye', 'Take care', 'Catch you later'],
        'responses': ['Goodbye!', 'See you later!', 'Take care!', 'Until next time!']
    },
    {
        'tag': 'thanks',
        'patterns': ['Thank you', 'Thanks', 'Thanks a lot', 'I appreciate it', 'Much obliged'],
        'responses': ["You're welcome!", "No problem!", "Glad I could help!", "Anytime!"]
    },
    {
        'tag': 'about',
        'patterns': ['What can you do', 'Who are you', 'What are you', 'What is your purpose', 'Tell me about yourself'],
        'responses': ["I’m a chatbot designed to assist you!", "I'm here to help with your questions.", "I can chat, provide information, and assist with various topics!"]
    },
    {
        'tag': 'help',
        'patterns': ['Help', 'I need help', 'Can you help me', 'What should I do', 'I’m stuck'],
        'responses': ["Of course! What do you need help with?", "I'm here to assist. Tell me the issue!", "Let me know how I can help!"]
    },
    {
        'tag': 'age',
        'patterns': ['How old are you', 'What’s your age', 'When were you created'],
        'responses': ["I don't have an exact age, but I'm always learning!", "I exist in the digital world, so I don't age!", "Time doesn’t affect me, but I’m always improving!"]
    },
    {
        'tag': 'weather',
        'patterns': ['What’s the weather like', 'How’s the weather today', 'Tell me today’s forecast'],
        'responses': ["I can't check real-time weather, but you can try a weather app!", "You can check the weather on Google or a weather website."]
    },
    {
        'tag': 'budget',
        'patterns': ['How can I make a budget', 'What’s a good budgeting strategy', 'How do I create a budget', 'Best way to manage money'],
        'responses': [
            "Start by tracking your income and expenses. Then, divide your budget into needs, savings, and wants.",
            "A popular budgeting method is the 50/30/20 rule: 50% on needs, 30% on wants, and 20% on savings and debt repayment.",
            "Use budgeting apps like Mint or YNAB to track spending and create a financial plan!"
        ]
    },
    {
        'tag': 'credit_score',
        'patterns': ['What is a credit score', 'How do I check my credit score', 'How can I improve my credit score', 'Why is credit score important'],
        'responses': [
            "A credit score is a number that represents your creditworthiness, based on your financial history.",
            "You can check your credit score for free on sites like Credit Karma, Experian, or your bank’s website.",
            "To improve your credit score: pay bills on time, keep credit utilization low, and avoid opening too many new accounts."
        ]
    },
    {
        'tag': 'fallback',
        'patterns': ['I don’t understand', 'What do you mean', 'That doesn’t make sense', 'Explain again'],
        'responses': ["I'm not sure I understand. Could you rephrase?", "I didn't get that. Can you say it differently?", "I'm still learning! Can you ask in another way?"]
    }
]
